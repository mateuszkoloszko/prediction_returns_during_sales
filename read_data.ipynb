# %% [markdown]
# # wczytanie danych

# %%
import pandas as pd
import numpy as np
import sqlalchemy as sa
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score

# %%
df_retu1 = pd.read_excel('dane.xlsx')

# %%
df_retu = df_retu1.copy()

# %% [markdown]
# # zapoznanie się z danymi

# %% [markdown]
# ## ogólne info o danych

# %%
df_retu.head()
# Out:
#     Season Channel       STCL  ClearanceWeek  RETU   Subclass  SLSU  \
# 0  AW 2023  RETAIL  0347N-01X              2   0.0  L_premium   NaN
# 1  AW 2023  RETAIL  0347N-01X              3   0.0  L_premium   NaN
# 2  AW 2023  RETAIL  0347N-01X              4  -1.0  L_premium   NaN
# 3  AW 2023  RETAIL  0347N-01X              5  -1.0  L_premium   NaN
# 4  AW 2023  RETAIL  0347N-01X              6   0.0  L_premium   NaN
#
#    PriceDiffFromLastRegular  StockCalculationDate  Last2DaysSLSU  \
# 0                    0.3846                  10.0              0
# 1                    0.3846                  18.0              0
# 2                    0.6923                  25.0              0
# 3                    0.7693                  26.0              2
# 4                    0.7693                  19.0              2
#
#    Last3DaysSLSU  Last4DaysSLSU  Last5DaysSLSU  BeforeClearanceSeasonSLSU  \
# 0              0              0              0                        0.0
# ...

# %%
df_retu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295263 entries, 0 to 295262
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Season                         295263 non-null  object
#  1   Channel                        295263 non-null  object
#  2   STCL                           295263 non-null  object
#  3   ClearanceWeek                  295263 non-null  int64
#  4   RETU                           295263 non-null  float64
#  5   Subclass                       295263 non-null  object
#  6   SLSU                           258471 non-null  float64
#  7   PriceDiffFromLastRegular       288720 non-null  float64
#  8   StockCalculationDate           282918 non-null  float64
#  9   Last2DaysSLSU                  295263 non-null  int64
#  10  Last3DaysSLSU                  295263 non-null  int64
#  11  Last4DaysSLSU                  295263 non-null  int64
# ...

# %%
df_retu.shape
# Out:
# (295263, 20)

# %%
df_retu.describe()
# Out:
#        ClearanceWeek           RETU           SLSU  PriceDiffFromLastRegular  \
# count  295263.000000  295263.000000  258471.000000             288720.000000
# mean        6.000000     -10.493872      63.907672                  0.465137
# std         2.581993      23.588379     114.108061                  0.174952
# min         2.000000    -799.000000       0.000000                 -0.498600
# 25%         4.000000     -11.000000      10.000000                  0.363700
# 50%         6.000000      -2.000000      29.000000                  0.500000
# 75%         8.000000       0.000000      70.000000                  0.600000
# max        10.000000       0.000000    3504.000000                  0.913400
#
#        StockCalculationDate  Last2DaysSLSU  Last3DaysSLSU  Last4DaysSLSU  \
# count         282918.000000   295263.00000  295263.000000  295263.000000
# mean             269.676465       16.86259      28.102614      39.672197
# ...

# %%
df_retu.describe(include=['object'])
# Out:
#          Season Channel       STCL          Subclass FabricComposition  \
# count    295263  295263     295263            295263            295218
# unique        6       3      19084                38              1394
# top     SS 2022  RETAIL  1920P-80X  JER_t-shirts_s_s        100%Cotton
# freq      63882  166257         27             33244             51642
#
#               Line
# count       295263
# unique           4
# top     BLACK LINE
# freq        146493

# %%
df_retu.nunique()
# Out:
# Season                               6
# Channel                              3
# STCL                             19084
# ClearanceWeek                        9
# RETU                               412
# Subclass                            38
# SLSU                              1360
# PriceDiffFromLastRegular           389
# StockCalculationDate              3859
# Last2DaysSLSU                      502
# Last3DaysSLSU                      745
# Last4DaysSLSU                      952
# Last5DaysSLSU                     1246
# BeforeClearanceSeasonSLSU         4542
# Last2WeeksBeforeClearanceSLSU     1259
# SbclSLSULY                        2068
# FabricComposition                 1394
# Line                                 4
# PredictionsSLSU                    778
# RETU_Regular                       447
# dtype: int64

# %%
for col in df_retu.select_dtypes(include=['object']).columns:
    print(f"{col}:\n{df_retu[col].value_counts()}\n")
# Out:
# Season:
# Season
# SS 2022    63882
# SS 2021    52920
# SS 2023    51354
# AW 2021    48123
# AW 2022    42192
# AW 2023    36792
# Name: count, dtype: int64
#
# Channel:
# Channel
# RETAIL    166257
# ECOM      128906
# ECOMMM       100
# Name: count, dtype: int64
#
# STCL:
# STCL
# 1920P-80X    27
# 3019P-55X    27
# 6804B-59J    18
# 6823B-05J    18
# 1394C-01X    18
#              ..
# 1566I-99X     9
# 1567C-08X     9
# 1572C-84X     9
# 1572I-33X     9
# 9889M-39X     9
# Name: count, Length: 19084, dtype: int64
#
# Subclass:
# Subclass
# JER_t-shirts_s_s         33244
# B_dresses                18423
# JER_dresses              15669
# B_shirts                 14652
# B_trousers               14580
# W_dresses                14398
# W_shirts                 12483
# JER_trousers             11637
# jeans_trousers           11232
# JER_t-shirts_l_s         10944
# OUTWEAR_medium           10179
# KNIT_blouse               9540
# W_trousers                9423
# ...

# %% [markdown]
# ## null

# %%
df_retu.isnull().sum()
# Out:
# Season                                0
# Channel                               0
# STCL                                  0
# ClearanceWeek                         0
# RETU                                  0
# Subclass                              0
# SLSU                              36792
# PriceDiffFromLastRegular           6543
# StockCalculationDate              12345
# Last2DaysSLSU                         0
# Last3DaysSLSU                         0
# Last4DaysSLSU                         0
# Last5DaysSLSU                         0
# BeforeClearanceSeasonSLSU             0
# Last2WeeksBeforeClearanceSLSU         0
# SbclSLSULY                            0
# FabricComposition                    45
# Line                                  0
# PredictionsSLSU                  207117
# RETU_Regular                          0
# dtype: int64

# %%
missing_percent = df_retu.isnull().mean() * 100
print(missing_percent)
# Out:
# Season                           0.0
# Channel                          0.0
# STCL                             0.0
# ClearanceWeek                    0.0
# RETU                             0.0
# Subclass                         0.0
# SLSU                             0.0
# PriceDiffFromLastRegular         0.0
# StockCalculationDate             0.0
# Last2DaysSLSU                    0.0
# Last3DaysSLSU                    0.0
# Last4DaysSLSU                    0.0
# Last5DaysSLSU                    0.0
# BeforeClearanceSeasonSLSU        0.0
# Last2WeeksBeforeClearanceSLSU    0.0
# SbclSLSULY                       0.0
# FabricComposition                0.0
# Line                             0.0
# PredictionsSLSU                  0.0
# RETU_Regular                     0.0
# dtype: float64
